# %%
import numpy as np
from  math import *
import matplotlib.pyplot as plt
import scipy.optimize as so
import scipy.special as sp
import mpmath as mp

# was hat es mit dem p_0 auf sich? bzw kann man das nicht in eine globale Varibale verwandeln


# N_x=10
# N_y=10
# T=1
# J=0.5/T

N_md = 100 #Leapfrog integration steps
N_en = 10
N_cfg = 2 #was ist das? 
beta=1
N=20
h=0.5
beta_h=0.5
J=1/N
phi_0 = 0
p_0 = 0 
I = 10
A = 1 #kann auf 1, weil wir so gut wie keine Autocorrelation mehr haben
p = np.random.normal(loc=0.0, scale=1.0) #wieso? das P bekommen wir doch auch aus dem leapfrog

# %%
def calc_magn(phi_en): 
    global beta_h
    global N_cfg
    global N_en
    global I
    global A
    
    M_array = np.zeros(N_en)
    M_array_I = np.zeros(int((N_en-I)/A))
    
    for i in range(N_en):
        phi_v = phi_en[i] #wieso zwischenvariable? 
        M_array[i] = np.tanh(beta_h+phi_v) 
      
        
    M=0
    
    M_array_I = M_array[I::A]
    
    
    M=np.sum(M_array)
    
    return M/N_cfg

# %%
def calc_eps(phi_en): 
    global beta_h
    global h
    global beta
    global N_cfg
    
    e_array = np.zeros(N_en)
        
    for i in range(len(phi_en)):
        
        e_array[i]= (phi_en[i]**2-3*beta)/(3*beta**2)*1/(N_cfg)+h*mp.tanh(beta_h+phi_en[i])
    
    e = np.sum(e_array)
    
    return -e/N_cfg

# %%
def f(n):
    #global n
    global J
    global beta_J
    global beta_h
    global N_cfg
    global x
    
    return(np.exp((beta*J*(N_cfg-n)**2)/2+beta_h*(N_cfg-n)))

# %%
def partition_func_theo():
    global beta_h
    global N_cfg
    global beta_J
    
    Z = 0
    
    for n in range(N_cfg+1):
        x = N_cfg-2*n
        Z += sp.binom(N_cfg, n)*f(n)
    
    return(Z)

# %%
def beta_eps_theo():
    global N_cfg
    global beta_J
    global beta_h
    
    value = 0
    
    for n in range(N_cfg+1):
        
        value += sp.binom(N_cfg, n)*(1/2*beta*J*(N_cfg-2*n)**2+beta_h*(N_cfg-2*n))*f(N_cfg-2*n)
    
    value = -value/(N_cfg*partition_func_theo())
    
    return(value)

# %%
def m_theo():
    global N_cfg
    global beta_J
    global beta_h
    
    value = 0
    
    for n in range(N_cfg+1):
        x = N_cfg-2*n
        value += sp.binom(N_cfg, n)*(N_cfg-2*n)*f(n)
        
    value = value/(N_cfg*partition_func_theo())
        
    return(value)

# %%
def leapfrog(p_0,phi_0):
    global beta 
    global J
    global N 
    global h
    global N_md
    
    eps=1/N_md
    phi=phi_0+eps/2*p_0
    p=p_0
    for i in range(N_md-1):
        p=p-eps*(phi/(beta*J)-N*mp.tanh(beta*h+phi))
        phi=phi+eps*p
    p=p-eps*(phi/(beta*J)-N*mp.tanh(beta*h+phi))
    phi=phi+eps/2*p
    
    return[p,phi]

# %%
def H(p,phi):
    global beta 
    global J 
    global h 
    
    return p**2/2+phi**2/(2*beta*J)-N*mp.log(2*mp.cosh(beta*h+phi))

# %%
def HMC(): #Does one iteration of the Markov-Chain and return phi
    global N_md
    global p_0
    global phi_0
    global p
    
    p = np.random.normal(loc=0.0, scale=1.0) #wieso? das P bekommen wir doch auch aus dem leapfrog
    
    phi_l = leapfrog(p,phi_0)[1]
    p_l =leapfrog(p,phi_0)[0]
    
    if np.exp(float(H(p,phi_0)-H(p_l,phi_l)))<1:
        P_acc = np.exp(float(H(p,phi_0)-H(p_l,phi_l)))
    else:
        P_acc = 1
        
    if P_acc > np.random.rand(): 
        #p = p_l
        phi_0 = phi_l
        p = p_l
        ar=+1
        
#    a_rate = ar/(N_x*N_y)*100
    
    return(phi_0, ar)

# %%
def ensemble(): #Generates an ensemble of phi and counts the acceptance rate
    global N_en
    global N_md
    global p_0
    global phi_0
    
    phi_en_calc =np.zeros(N_en)
    ar = 0
    
    for i in range(N_en):
        phi_en_calc[i] = HMC()[0]
       # print(phi_0)
       # print(phi_en_calc)
    
    ar = HMC()[1]/N_en*100
    
    return(phi_en_calc, ar)

# %%
def m_J_5():  
#     global N_x
#     global N_y
    global h
    global N_cfg
    global beta_J
    global I
    global A
    global ar
    
    E=20 #amount of points for the graph
    #I=10 #initialization
    #A=15 #autocorrelationcorrection
    C=1000 #Number of components for an ensemble
    D=4

    
    colours=['b','g','r','c','m','y','k']    
    J_x = np.zeros(E+1)
    theo_values = np.zeros(E+1)
    for m in range(D): #different lattice sizes      
        N_cfg=(m+1)*5
        final_M=np.zeros(E+1)
        
        for j in range(E+1): #Calculation for different J
            J=beta_J=(0.2+(j/10))/N_cfg      # J=beta*J \in [0.2, 2.2) #J sollte in einheiten 1/N sein
            J_x[j]=J*N_cfg
            phi_en = ensemble()[0]    
            final_M[j] = calc_magn(phi_en)
            theo_values[j] = -m_theo()
            #print(final_M)
            
        print("Acceptance rate for lattice size ", N_cfg," :", ensemble()[1])
        plt.plot(J_x,final_M,color=colours[m+1],\
                 label='$N_{cfg}=$%s'%str(N_cfg))
        plt.plot(J_x,theo_values, color=colours[m+1], linestyle='dashed', label='Theoriewert für $N_{cfg}=$%s'%str(N_cfg))
    plt.legend()
    plt.xlabel(r"$J$")
    plt.ylabel(r"$m(J)$")
    plt.show()

# %%
m_J_5()
# Out:
# Acceptance rate for lattice size  5  : 10.0
# Acceptance rate for lattice size  10  : 10.0
# Acceptance rate for lattice size  15  : 10.0
# Acceptance rate for lattice size  20  : 10.0

# %%
def e_J_5():  
#     global N_x
#     global N_y
    global h
    global N_cfg
    global beta_J
    global I
    global A
    
    E=20 #amount of points for the graph
    #I=100 #initialization
    #A=15 #autocorrelationcorrection
    C=1000 #Number of components for an ensemble
    D=4
    
    final_eps=np.zeros(E+1) 
    M=0
    J_x = np.zeros(E+1)
    phi_en = ensemble()[0]      # ist diese Zeile nicht doppelt und könnte damit einmal entfernt werden?
    colours=['b','g','r','c','m','y','k']    
    theo_values = np.zeros(E+1)
    
    for m in range(D): #different lattice sizes      
        N_cfg=(m+1)*5
        final_M=np.zeros(E+1)
        
        for j in range(E+1): #Calculation for different J
            J=beta_J=0.2+(j/10)      # J=beta*J \in [0.2, 2.2)
            J_x[j]=J
            phi_en = ensemble()[0]    
            final_eps[j] = calc_eps(phi_en)
            theo_values[j] = beta_eps_theo()
            
        print("Acceptance rate for lattice size ", N_cfg," :", ensemble()[1])
        plt.plot(J_x,final_eps,color=colours[m+1],\
                 label='$N_{cfg}=$%s'%str(N_cfg))
        plt.plot(J_x,theo_values, color=colours[m+1], linestyle='dashed', label='Theoriewert für $N_{cfg}=$%s'%str(N_cfg))
    plt.legend()
    plt.xlabel(r"$J$")
    plt.ylabel(r"$e(J)$")
    plt.show()

# %%
e_J_5()
# Out:
# Acceptance rate for lattice size  5  : 10.0
# Acceptance rate for lattice size  10  : 10.0
# Acceptance rate for lattice size  15  : 10.0
# Acceptance rate for lattice size  20  : 10.0
